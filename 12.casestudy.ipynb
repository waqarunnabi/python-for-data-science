# %% [markdown]
# ## Pandas Case Study
# #### We will check the data from Kashti dataset

# %%
# import libaraies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# saving datafram into csv file
kashti.to_csv("kashti.csv")

# %%
# basic statistic or summary
kashti.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# droping few colums and make a new data set
new_kashti = kashti.drop(['deck','alone'], axis=1)
new_kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive
# 0    man        True  Southampton    no
# 1  woman       False    Cherbourg   yes
# 2  woman       False  Southampton   yes
# 3  woman       False  Southampton   yes
# 4    man        True  Southampton    no

# %%
# Same used
kashti.drop(['deck','alone'], axis=1).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive
# 0    man        True  Southampton    no
# 1  woman       False    Cherbourg   yes
# 2  woman       False  Southampton   yes
# 3  woman       False  Southampton   yes
# 4    man        True  Southampton    no

# %%
kashti.mean()
# Out:
# C:\Users\WAQARU~1\AppData\Local\Temp/ipykernel_4680/3332994036.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kashti.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
kashti.value_counts(['survived'])
# Out:
# survived
# 0           549
# 1           342
# dtype: int64

# %%
kashti.groupby(['sex']).mean()
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %%
kashti.groupby(['sex', 'class']).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.968085     1.0  34.611765  0.553191  0.457447  106.125798
#        Second  0.921053     2.0  28.722973  0.486842  0.605263   21.970121
#        Third   0.500000     3.0  21.750000  0.895833  0.798611   16.118810
# male   First   0.368852     1.0  41.281386  0.311475  0.278689   67.226127
#        Second  0.157407     2.0  30.740707  0.342593  0.222222   19.741782
#        Third   0.135447     3.0  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.361702
#        Second    0.000000  0.421053
#        Third     0.000000  0.416667
# male   First     0.975410  0.614754
#        Second    0.916667  0.666667
#        Third     0.919308  0.760807

# %%
# reason children and women first
kashti[kashti['age'] < 18].mean()
# Out:
# C:\Users\WAQARU~1\AppData\Local\Temp/ipykernel_4680/1894375963.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kashti[kashti['age'] < 18].mean()
# survived       0.539823
# pclass         2.584071
# age            9.041327
# sibsp          1.460177
# parch          1.053097
# fare          31.220798
# adult_male     0.159292
# alone          0.203540
# dtype: float64

# %%
# children
kashti[kashti['age'] < 18].groupby(['sex', 'class']).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.875000     1.0  14.125000  0.500000  0.875000  104.083337
#        Second  1.000000     2.0   8.333333  0.583333  1.083333   26.241667
#        Third   0.542857     3.0   8.428571  1.571429  1.057143   18.727977
# male   First   1.000000     1.0   8.230000  0.500000  2.000000  116.072900
#        Second  0.818182     2.0   4.757273  0.727273  1.000000   25.659473
#        Third   0.232558     3.0   9.963256  2.069767  1.000000   22.752523
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.125000
#        Second    0.000000  0.166667
#        Third     0.000000  0.228571
# male   First     0.250000  0.000000
#        Second    0.181818  0.181818
#        Third     0.348837  0.232558

# %% [markdown]
#  ### you have to go to FAO website
#  ### apni marzi ka data le
#  ### work exectly same like i did and send it to via telegram. only pdf files

# %%
# pip install faodata

# %%
# import faodata as fao

# %%
# sns.get_dataset_names()

# %%
# fao.get_dataset_names()

# %%
fod = pd.read_csv("data/Average_protein.csv")
fod
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 0           FS  Suite of Food Security Indicators        165  Pakistan
# 1           FS  Suite of Food Security Indicators        165  Pakistan
# 2           FS  Suite of Food Security Indicators        165  Pakistan
# 3           FS  Suite of Food Security Indicators        165  Pakistan
# 4           FS  Suite of Food Security Indicators        165  Pakistan
# 5           FS  Suite of Food Security Indicators        165  Pakistan
# 6           FS  Suite of Food Security Indicators        165  Pakistan
# 7           FS  Suite of Food Security Indicators        165  Pakistan
# 8           FS  Suite of Food Security Indicators        165  Pakistan
# 9           FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 11          FS  Suite of Food Security Indicators        165  Pakistan
# ...

# %%
fod.head()
# Out:
#   Domain Code                             Domain  Area Code      Area  \
# 0          FS  Suite of Food Security Indicators        165  Pakistan
# 1          FS  Suite of Food Security Indicators        165  Pakistan
# 2          FS  Suite of Food Security Indicators        165  Pakistan
# 3          FS  Suite of Food Security Indicators        165  Pakistan
# 4          FS  Suite of Food Security Indicators        165  Pakistan
#
#    Element Code Element  Item Code  \
# 0          6132   Value     210011
# 1          6132   Value     210011
# 2          6132   Value     210011
# 3          6132   Value     210011
# 4          6132   Value     210011
#
#                                                 Item  Year Code       Year  \
# 0  Number of people undernourished (million) (3-y...   20002002  2000-2002
# 1  Number of people undernourished (million) (3-y...   20012003  2001-2003
# 2  Number of people undernourished (million) (3-y...   20022004  2002-2004
# ...

# %%
pop = pd.read_csv("data/population_pk_17-19.csv")
pop
# Out:
#              city            province   country  total_pop urban_pop  \
# 0      Abbottabad  Khyber Pakhtunkhwa  Pakistan  1,332,912   293,137
# 1          Attock              Punjab  Pakistan  1,883,556   490,006
# 2          Awaran         Balochistan  Pakistan    121,680    34,244
# 3           Badin               Sindh  Pakistan  1,804,516   390,378
# 4    Bahawalnagar              Punjab  Pakistan  2,981,919   621,096
# ..            ...                 ...       ...        ...       ...
# 126     Upper Dir  Khyber Pakhtunkhwa  Pakistan    946,421    44,165
# 127        Vehari              Punjab  Pakistan  2,897,446   505,703
# 128        Washuk         Balochistan  Pakistan    176,206    21,872
# 129          Zhob         Balochistan  Pakistan    310,544    46,248
# 130        Ziarat         Balochistan  Pakistan    160,422     3,406
#
#      rural_pop total_male total_female total_trans
# 0    1,039,775    677,570      655,281          61
# ...

# %%
pop.head()
# Out:
#            city            province   country  Total_pop Urban_pop  Rural_pop  \
# 0    Abbottabad  Khyber Pakhtunkhwa  Pakistan  1,332,912   293,137  1,039,775
# 1        Attock              Punjab  Pakistan  1,883,556   490,006  1,393,550
# 2        Awaran         Balochistan  Pakistan    121,680    34,244     87,436
# 3         Badin               Sindh  Pakistan  1,804,516   390,378  1,414,138
# 4  Bahawalnagar              Punjab  Pakistan  2,981,919   621,096  2,360,823
#
#   Total_male_population Total_female_population Total_transgender_population
# 0               677,570                 655,281                           61
# 1               936,811                 946,683                           62
# 2                63,023                  58,657                            0
# 3               932,488                 871,979                           49
# 4             1,514,866               1,466,876                          177

# %%
pop.describe()
# Out:
#               city            province   country  Total_pop Urban_pop  \
# count          131                 131       131        131       131
# unique         131                   5         1        131       116
# top     Abbottabad  Khyber Pakhtunkhwa  Pakistan  1,332,912         0
# freq             1                  38       131          1        16
#
#         Rural_pop Total_male_population Total_female_population  \
# count         131                   131                     131
# unique        131                   131                     131
# top     1,039,775               677,570                 655,281
# freq            1                     1                       1
#
#        Total_transgender_population
# count                           131
# unique                           78
# top                               0
# freq                             24

# %%
# pop.mean()
# Out:
# C:\Users\WAQARU~1\AppData\Local\Temp/ipykernel_4680/431921984.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pop.mean()
# Series([], dtype: float64)

# %%
# new_pop = pop.drop(['admin0Pcode','admin1Pcode','admin2Pcode'], axis=1)
# new_pop.head()
# Out:
#   admin2Name_en       admin1Name_en admin0Name_en  Total_pop Urban_pop  \
# 0    Abbottabad  Khyber Pakhtunkhwa      Pakistan  1,332,912   293,137
# 1        Attock              Punjab      Pakistan  1,883,556   490,006
# 2        Awaran         Balochistan      Pakistan    121,680    34,244
# 3         Badin               Sindh      Pakistan  1,804,516   390,378
# 4  Bahawalnagar              Punjab      Pakistan  2,981,919   621,096
#
#    Rural_pop Total_male_population Total_female_population  \
# 0  1,039,775               677,570                 655,281
# 1  1,393,550               936,811                 946,683
# 2     87,436                63,023                  58,657
# 3  1,414,138               932,488                 871,979
# 4  2,360,823             1,514,866               1,466,876
#
#   Total_transgender_population
# 0                           61
# 1                           62
# 2                            0
# 3                           49
# ...

# %%
pop.groupby(['city','total_male', 'total_female','total_trans']).mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# ...

# %%
pop.groupby(['city','total_trans']).mean()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# ...
